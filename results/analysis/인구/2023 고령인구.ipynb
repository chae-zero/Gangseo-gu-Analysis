# %% [markdown]
# ### 라이브러리 불러오기

# %%
import openpyxl

# %%
import numpy as np
import pandas as pd
# import glob

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rc('font', family='Malgun Gothic')
sns.set(font="Malgun Gothic",
        rc={"axes.unicode_minus":False}, # 마이너스 부호 깨짐 현상 해결
        style='darkgrid')  

import warnings
warnings.filterwarnings(action='ignore')
# %config InlineBackend.figure_format = 'retina'

# %%
path = 'data/2023 고령인구 비율.csv'
data = pd.read_csv(path)

data.head(20)
# Out:
#   행정구역  고령인구비율(%)
# 0   전국         18
# 1  강서구         17

# %%
plt.figure(figsize=(8,4))
sns.barplot(x=data['행정구역'] , y=data['고령인구비율(%)'])
plt.title('2023 고령 인구 비율', size=15)
plt.axhline(14, c='r', linestyle='--')  # 14% 이상부터 고령 사회
plt.ylim(0.0, 20.0) # 20% 이상부터 초고령 사회
plt.show()
